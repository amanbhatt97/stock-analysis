# %%
from datetime import date

import matplotlib.pyplot as plt
# Set the default figure size
plt.rcParams['figure.figsize'] = (12, 8)

from src.data_fetch import get_daily_price

# %%
df = get_daily_price('SBIN', date(2018,1,1), date(2023,7,4))

# %%
df = df[['DATE', 'CLOSE', '52W H', '52W L', 'VOLUME']]

# %%
df
# Out:
#            DATE   CLOSE   52W H   52W L    VOLUME
# 0    2023-07-03  585.45  629.55  466.85  15421985
# 1    2023-06-30  572.85  629.55  458.00   8718232
# 2    2023-06-28  569.80  629.55  458.00  18028934
# 3    2023-06-27  566.10  629.55  458.00  10694768
# 4    2023-06-26  557.05  629.55  458.00   8360264
# ...         ...     ...     ...     ...       ...
# 1368 2018-01-05  306.35  351.30  241.10  14580575
# 1369 2018-01-04  308.50  351.30  241.10  24517099
# 1370 2018-01-03  302.85  351.30  241.10  13857373
# 1371 2018-01-02  303.25  351.30  241.10  14797364
# 1372 2018-01-01  307.10  351.30  241.10  12182400
#
# [1373 rows x 5 columns]

# %%
df.set_index('DATE')[['CLOSE', '52W H', '52W L']].plot()
# Out:
# <Axes: xlabel='DATE'>
