# %%
from datetime import *
import pandas as pd

import plotly.express as px
import matplotlib.pyplot as plt
plt.rcParams['figure.figsize'] = (12, 8)

# get to the parent directory
import sys
sys.path.append('..')   # for notebook uncomment this
# sys.path.append(os.path.join(os.path.dirname(__file__), '..'))   # for script uncomment this

# %%
from src.data_fetch import get_daily_price

# %%
symbol = 'SBIN'

# %%
df = get_daily_price(symbol, date(2021,1,1), datetime.now().date())

# %%
# df = df[['DATE', 'CLOSE', '52W H', '52W L', 'VOLUME']]

# %%
df
# Out:
#           DATE SERIES    OPEN    HIGH     LOW  PREV. CLOSE     LTP   CLOSE  \
# 0   2023-08-31     EQ  569.30  570.30  559.40       567.40  562.15  561.35
# 1   2023-08-30     EQ  576.70  577.70  566.10       574.85  567.50  567.40
# 2   2023-08-29     EQ  573.65  576.30  571.85       572.85  575.25  574.85
# 3   2023-08-28     EQ  572.80  574.80  569.20       569.95  573.10  572.85
# 4   2023-08-25     EQ  573.80  575.30  567.20       576.95  569.70  569.95
# ..         ...    ...     ...     ...     ...          ...     ...     ...
# 656 2021-01-07     EQ  289.00  291.80  287.00       285.05  288.00  287.70
# 657 2021-01-06     EQ  283.00  289.15  281.40       281.75  283.90  285.05
# 658 2021-01-05     EQ  278.05  282.45  277.00       281.05  281.40  281.75
# 659 2021-01-04     EQ  281.85  283.90  277.75       279.40  281.10  281.05
# 660 2021-01-01     EQ  274.90  280.00  274.40       274.95  279.05  279.40
#
# ...

# %%
import plotly.graph_objects as go

# %%
# Convert the 'DATE' column to datetime
df['DATE'] = pd.to_datetime(df['DATE'])

# Create a Plotly figure
fig = go.Figure()

# Add the main line plot
fig.add_trace(go.Scatter(x=df['DATE'], y=df['CLOSE'], name='CLOSE'))

# Add a vertical line and annotation
vline_date = df['DATE'][2]
vline_close = df['CLOSE'][2]

# Update the layout
fig.update_layout(title=f'{symbol}-Stock Price over Time', hovermode="x unified",
)

# Show the interactive plot
fig.show()
# Out:
# /Users/amanbhatt/Desktop/Projects/stock-analysis/stock_env/lib/python3.10/site-packages/_plotly_utils/basevalidators.py:105: FutureWarning:
#
# The behavior of DatetimeProperties.to_pydatetime is deprecated, in a future version this will return a Series containing python datetime objects instead of an ndarray. To retain the old behavior, call `np.array` on the result
